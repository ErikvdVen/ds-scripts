# %% [markdown]
# # Transforming multi-level JSON datastructures to a DataFrame

# %%
# Import Libraries
import json
import pandas as pd

# %%
# Open JSON file
file = open('./scraped_tiktok_data.json', encoding="utf8")
# Parse JSON
data = json.load(file)
# Close file
file.close()
# Show amount of objects
len(data['collector'])
# Out:
# 1000

# %%
# Show example of object
print(json.dumps(data['collector'][4], indent=4, sort_keys=True))
# Out:
# {
#     "authorMeta": {
#         "avatar": "https://p16-sign-sg.tiktokcdn.com/aweme/1080x1080/tiktok-obj/4f9de35c02f5c80f9f65f68cbfd0dbc6.jpeg?x-expires=1608649200&x-signature=COgIVuObUTGyUtkmBf5k2FTCDX0%3D",
#         "id": "6586854399372394498",
#         "name": "io.dreamer_mk",
#         "nickName": "io. Dreamer",
#         "secUid": "MS4wLjABAAAAqwdQMoXzQWa8Zg8uIlLjIzNDK9dJ_0hiNKep9Mb6vXXL9mgy5kH4wdJD-pFEOuQs",
#         "signature": "Dance tutorial\ud83c\udf0f\ud83e\udd0d\n\u52d5\u753b\u30ec\u30af\u30c1\u30e3\u30fc/\u6559\u5ba4\u306f\u30a4\u30f3\u30b9\u30bf\u306bDM\u3092 YouTube\u2192mkmkmk.m99\ninstagram\u2192io.dreamer",
#         "verified": false
#     },
#     "commentCount": 52,
#     "covers": {
#         "default": "https://p16-sign-sg.tiktokcdn.com/obj/tos-alisg-p-0037/169f4b67ab9f4f408dd8a97debf7f12b?x-expires=1608584400&x-signature=oa8AHwNaJ9ezWdU2XaGMD7SFb4E%3D",
#         "dynamic": "https://p16-sign-sg.tiktokcdn.com/obj/tos-alisg-p-0037/8abf150b6bd24c77a3dcab0bea24c2aa_1607843603?x-expires=1608584400&x-signature=IgaSXOgvF4V8UUjBxXuF9saVfBU%3D",
#         "origin": "https://p16-sign-sg.tiktokcdn.com/obj/tos-alisg-p-0037/bf87b97129a04fc291e09e27678d626b_1607843607?x-expires=1608584400&x-signature=%2B8oxG1RN7BR19jaFPF6tIdc1ypY%3D"
#     },
#     "createTime": 1607843600,
#     "diggCount": 8805,
#     "downloaded": true,
#     "hashtags": [
#         {
#             "cover": "https://p77-sg.tiktokcdn.com/obj/tiktok-obj/8493b75559c67c7a23d0094032f0ae07",
#             "id": "1627704798586882",
#             "name": "tiktok\u6559\u5ba4",
#             "title": "\u4eca\u56de\u306e #TikTok\u6559\u5ba4 -\u4eca\u5e74\u5b66\u3093\u3060\u77e5\u8b58\u7de8-\u3067\u306f\u3001\u8272\u3005\u3042\u3063\u305f2020\u5e74\u3042\u306a\u305f\u304c\u5b66\u3093\u3060\u77e5\u8b58\u3092\u6295\u7a3f\u3057\u3088\u3046\u3002\n\u3069\u3093\u306a\u30b8\u30e3\u30f3\u30eb\u306e\u6295\u7a3f\u3067\u3082OK\uff01  \u601d\u308f\u305a\u300c\u3078\u3047\u30fc\u300d\u300c\u77e5\u3089\u306a\u304b\u3063\u305f\u300d\u300c\u9762\u767d\u3044\uff01\u300d\u3068\u306a\u308b\u3088\u3046\u306a\u30a8\u30d4\u30bd\u30fc\u30c9\u3092\u6295\u7a3f\u3057\u3088\u3046! \n\n\u512a\u79c0\u6295\u7a3f\u8005\u306b\u306f2\u4e07\u5186\u306e\u52d5\u753b\u5236\u4f5c\u652f\u63f4\u91d1\u306e\u30c1\u30e3\u30f3\u30b9\uff01 \u596e\u3063\u3066\u5fdc\u52df\u3057\u3088\u3046\uff01\n\n\u6295\u7a3f\u306b\u97f3\u58f0\u3084\u30c6\u30ad\u30b9\u30c8\u3092\u5165\u308c\u308b\u3068\u3088\u308a\u308f\u304b\u308a\u3084\u3059\u304f\u306a\u308b\u304b\u3082\uff1f"
#         },
#         {
#             "cover": "https://p16-sg.tiktokcdn.com/obj/musically-maliva-obj/eca4f0ac54dc4ed1b2cf76ee6566cdc0",
#             "id": "8166",
#             "name": "tutorial",
#             "title": "#AprendeEnTikTok c\u00f3mo hacer lo que sea! Mu\u00e9stranos un #Tutorial que tenemos que aprender! \ud83d\ude4c"
#         }
#     ],
#     "id": "6905635666588192002",
#     "mentions": [],
#     "musicMeta": {
#         "coverLarge": "https://p16-sign-sg.tiktokcdn.com/musically-maliva-obj/1631513959710790~c5_1080x1080.jpeg?x-expires=1608649200&x-signature=WkxnycD9FwF44PTrCHM3r74dLM0%3D",
#         "coverMedium": "https://p16-sign-sg.tiktokcdn.com/musically-maliva-obj/1631513959710790~c5_720x720.jpeg?x-expires=1608649200&x-signature=56CdQy2NpQWSboYJPnI1dDtvYcE%3D",
#         "coverThumb": "https://p16-sign-sg.tiktokcdn.com/musically-maliva-obj/1631513959710790~c5_100x100.jpeg?x-expires=1608649200&x-signature=dQD%2BXfBBiWzieuZN28C4Hnutg5U%3D",
#         "musicAuthor": "Mj.\u65e0\u540d\u6c0f",
#         "musicId": "6649693417590754053",
#         "musicName": "\u539f\u8072",
#         "musicOriginal": true,
#         "playUrl": "https://sf77-sg.tiktokcdn.com/obj/musically-maliva-obj/1623460306604038.mp3"
#     },
#     "playCount": 115300,
#     "shareCount": 198,
#     "text": "\u5c0f\u6280\u3067\u3059\ud83d\udc5f\u2728#tiktok\u6559\u5ba4#tutorial",
#     "videoMeta": {
#         "duration": 22,
#         "height": 1024,
#         "width": 576
#     },
#     "videoUrl": "https://v77.tiktokcdn.com/7622979a5ceb97c6da4ec1f6b9c23702/5fe11a71/video/tos/alisg/tos-alisg-pve-0037c001/f468dc17f7cf4a698e8be586c72b32e5/?a=1180&br=1856&bt=928&cd=0%7C0%7C1&cr=0&cs=0&cv=1&dr=3&ds=3&er=&l=2020122115574701019020909243127031&lr=tiktok&mime_type=video_mp4&qs=0&rc=M2xzNTVseDR1eTMzaTgzM0ApNTc4NDppMzs4Nzs1Zjo3ZGducWAwNl9fcl5fLS0vLzRzczEzM2BeM2E1Y2NiYl42YF46Yw%3D%3D&vl=&vr=",
#     "videoUrlNoWaterMark": "",
#     "webVideoUrl": "https://www.tiktok.com/@io.dreamer_mk/video/6905635666588192002"
# }

# %% [markdown]
# ## Fast Method
# So we would like to parse the JSON data in the following way:
# - `hashtags` and `mentions` are lists, so we would like to "explode" them: split the list and store it as separated rows, together with all other information (copying other fields);
#     - `hashtags` contains a list of objects, so we would like to split the objects to separate columns afterwords;
# - Split every other cell containing objects to separate columns

# %%
# This will split the objects to separate columns and store everything as a DataFrame
df = pd.json_normalize(data['collector'])
# Explode the fields containing lists, to separate rows
df = df.explode('hashtags').explode('mentions')
# Converting the dataframe back to JSON format, so we can normalize again
df = df.to_json(orient='records')
# Parse the JSON data
parsed_json = json.loads(df)
# Normalize again and recreate the dataframe
df = pd.json_normalize(parsed_json)
df
# Out:
#                        id                                               text  \
# 0     6907228749016714497                                  Confidence went 📈
# 1     6875468410612993286  Quiet Zone... follow me on insta: joeysofo. Co...
# 2     6898699405898059010  Iphone bend test🤗 #tiktok #viral #fyp #iphone ...
# 3     6898699405898059010  Iphone bend test🤗 #tiktok #viral #fyp #iphone ...
# 4     6898699405898059010  Iphone bend test🤗 #tiktok #viral #fyp #iphone ...
# ...                   ...                                                ...
# 5688  6899116261746281730  The collab you didn’t know you needed, myself ...
# 5689  6899116261746281730  The collab you didn’t know you needed, myself ...
# 5690  6899116261746281730  The collab you didn’t know you needed, myself ...
# 5691  6899116261746281730  The collab you didn’t know you needed, myself ...
# 5692  6899116261746281730  The collab you didn’t know you needed, myself ...
#
#       createTime                                        webVideoUrl  \
# 0     1608214517  https://www.tiktok.com/@ninakleij/video/690722...
# 1     1600819763  https://www.tiktok.com/@joeysofo/video/6875468...
# 2     1606228625  https://www.tiktok.com/@jackeyephone/video/689...
# 3     1606228625  https://www.tiktok.com/@jackeyephone/video/689...
# 4     1606228625  https://www.tiktok.com/@jackeyephone/video/689...
# ...          ...                                                ...
# 5688  1606325682  https://www.tiktok.com/@erinwilliams_1/video/6...
# 5689  1606325682  https://www.tiktok.com/@erinwilliams_1/video/6...
# 5690  1606325682  https://www.tiktok.com/@erinwilliams_1/video/6...
# 5691  1606325682  https://www.tiktok.com/@erinwilliams_1/video/6...
# 5692  1606325682  https://www.tiktok.com/@erinwilliams_1/video/6...
#
#                                                videoUrl videoUrlNoWaterMark  \
# 0     https://v77.tiktokcdn.com/ed1f811617d7b5e18b8d...
# 1     https://v77.tiktokcdn.com/ab935f1975cb8b69aebf...
# 2     https://v21.tiktokcdn.com/video/tos/alisg/tos-...
# 3     https://v21.tiktokcdn.com/video/tos/alisg/tos-...
# 4     https://v21.tiktokcdn.com/video/tos/alisg/tos-...
# ...                                                 ...                 ...
# 5688  https://v77.tiktokcdn.com/a6a5e4b4310213520be7...
# 5689  https://v77.tiktokcdn.com/a6a5e4b4310213520be7...
# 5690  https://v77.tiktokcdn.com/a6a5e4b4310213520be7...
# 5691  https://v77.tiktokcdn.com/a6a5e4b4310213520be7...
# 5692  https://v77.tiktokcdn.com/a6a5e4b4310213520be7...
#
#       diggCount  shareCount  playCount  commentCount  ...  \
# 0          3710          50      44800            68  ...
# 1         55700        1817     838100           936  ...
# 2        936200       21100   15300000         27100  ...
# 3        936200       21100   15300000         27100  ...
# 4        936200       21100   15300000         27100  ...
# ...         ...         ...        ...           ...  ...
# 5688      58900         235     309000           874  ...
# 5689      58900         235     309000           874  ...
# 5690      58900         235     309000           874  ...
# 5691      58900         235     309000           874  ...
# 5692      58900         235     309000           874  ...
#
#                                          covers.default  \
# 0     https://p16-sign-sg.tiktokcdn.com/obj/tos-alis...
# 1     https://p16-sign-sg.tiktokcdn.com/obj/tos-mali...
# 2     https://p16-sign-sg.tiktokcdn.com/obj/tos-alis...
# 3     https://p16-sign-sg.tiktokcdn.com/obj/tos-alis...
# 4     https://p16-sign-sg.tiktokcdn.com/obj/tos-alis...
# ...                                                 ...
# 5688  https://p16-sign-sg.tiktokcdn.com/tos-alisg-p-...
# 5689  https://p16-sign-sg.tiktokcdn.com/tos-alisg-p-...
# 5690  https://p16-sign-sg.tiktokcdn.com/tos-alisg-p-...
# 5691  https://p16-sign-sg.tiktokcdn.com/tos-alisg-p-...
# 5692  https://p16-sign-sg.tiktokcdn.com/tos-alisg-p-...
#
#                                           covers.origin  \
# 0     https://p16-sign-sg.tiktokcdn.com/obj/tos-alis...
# 1     https://p16-sign-sg.tiktokcdn.com/obj/tos-mali...
# 2     https://p16-sign-sg.tiktokcdn.com/obj/tos-alis...
# 3     https://p16-sign-sg.tiktokcdn.com/obj/tos-alis...
# 4     https://p16-sign-sg.tiktokcdn.com/obj/tos-alis...
# ...                                                 ...
# 5688  https://p16-sign-sg.tiktokcdn.com/obj/tos-alis...
# 5689  https://p16-sign-sg.tiktokcdn.com/obj/tos-alis...
# 5690  https://p16-sign-sg.tiktokcdn.com/obj/tos-alis...
# 5691  https://p16-sign-sg.tiktokcdn.com/obj/tos-alis...
# 5692  https://p16-sign-sg.tiktokcdn.com/obj/tos-alis...
#
#                                          covers.dynamic videoMeta.height  \
# 0     https://p16-sign-sg.tiktokcdn.com/obj/tos-alis...             1024
# 1     https://p16-sign-sg.tiktokcdn.com/obj/tos-mali...             1024
# 2     https://p16-sign-sg.tiktokcdn.com/obj/tos-alis...              960
# 3     https://p16-sign-sg.tiktokcdn.com/obj/tos-alis...              960
# 4     https://p16-sign-sg.tiktokcdn.com/obj/tos-alis...              960
# ...                                                 ...              ...
# 5688  https://p16-sign-sg.tiktokcdn.com/obj/tos-alis...             1022
# 5689  https://p16-sign-sg.tiktokcdn.com/obj/tos-alis...             1022
# 5690  https://p16-sign-sg.tiktokcdn.com/obj/tos-alis...             1022
# 5691  https://p16-sign-sg.tiktokcdn.com/obj/tos-alis...             1022
# 5692  https://p16-sign-sg.tiktokcdn.com/obj/tos-alis...             1022
#
#      videoMeta.width videoMeta.duration hashtags.id   hashtags.name  \
# 0                576                 15         NaN             NaN
# 1                576                 11         NaN             NaN
# 2                540                 19       23428          tiktok
# 3                540                 19       20884           viral
# 4                540                 19      229207             fyp
# ...              ...                ...         ...             ...
# 5688             576                 14      431293       horsegirl
# 5689             576                 14        8097      equestrian
# 5690             576                 14    17680889  equestriangirl
# 5691             576                 14        8664          riding
# 5692             576                 14        7883           horse
#
#      hashtags.title hashtags.cover
# 0               NaN            NaN
# 1               NaN            NaN
# 2
# 3
# 4
# ...             ...            ...
# 5688
# 5689
# 5690
# 5691
# 5692
#
# [5693 rows x 38 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5693 entries, 0 to 5692
# Data columns (total 38 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       5693 non-null   object
#  1   text                     5693 non-null   object
#  2   createTime               5693 non-null   int64
#  3   webVideoUrl              5693 non-null   object
#  4   videoUrl                 5693 non-null   object
#  5   videoUrlNoWaterMark      5693 non-null   object
#  6   diggCount                5693 non-null   int64
#  7   shareCount               5693 non-null   int64
#  8   playCount                5693 non-null   int64
#  9   commentCount             5693 non-null   int64
#  10  downloaded               5693 non-null   bool
#  11  mentions                 1316 non-null   object
#  12  hashtags                 0 non-null      float64
#  13  authorMeta.id            5693 non-null   object
#  14  authorMeta.secUid        5693 non-null   object
#  15  authorMeta.name          5693 non-null   object
#  16  authorMeta.nickName      5693 non-null   object
#  17  authorMeta.verified      5693 non-null   bool
#  18  authorMeta.signature     5693 non-null   object
#  19  authorMeta.avatar        5693 non-null   object
#  20  musicMeta.musicId        5693 non-null   object
#  21  musicMeta.musicName      5693 non-null   object
#  22  musicMeta.musicAuthor    5693 non-null   object
#  23  musicMeta.musicOriginal  5693 non-null   bool
#  24  musicMeta.playUrl        5693 non-null   object
#  25  musicMeta.coverThumb     5693 non-null   object
#  26  musicMeta.coverMedium    5693 non-null   object
#  27  musicMeta.coverLarge     5693 non-null   object
#  28  covers.default           5693 non-null   object
#  29  covers.origin            5693 non-null   object
#  30  covers.dynamic           5693 non-null   object
#  31  videoMeta.height         5693 non-null   int64
#  32  videoMeta.width          5693 non-null   int64
#  33  videoMeta.duration       5693 non-null   int64
#  34  hashtags.id              5540 non-null   object
#  35  hashtags.name            5540 non-null   object
#  36  hashtags.title           5540 non-null   object
#  37  hashtags.cover           5540 non-null   object
# dtypes: bool(3), float64(1), int64(8), object(26)
# memory usage: 1.5+ MB

# %% [markdown]
# We took advantage of Pandas vectorized functions, which made everything insanly fast. But there is a slower method as well, using the apply function on each row.
# This is just as an example. If you use the apply function and it takes quite long, look for ways to use vectorization.

# %% [markdown]
# ## Slow method

# %%
def object_to_columns(dfRow, **kwargs):
    '''Function to expand cells containing dictionaries, to columns'''
    for column, prefix in kwargs.items():
        if isinstance(dfRow[column], dict):
            for key, value in dfRow[column].items():
                columnName = '{}.{}'.format(prefix, key)
                dfRow[columnName] = value
    return dfRow

# Create a DataFrame of the data
df_tiktok_dataset = pd.DataFrame(data['collector'])

# Let's expand the hashtag cell containing lists to multiple rows
df_tiktok_dataset = df_tiktok_dataset.explode('hashtags').explode('mentions')

# Expand certain cells containing dictionaries to columns
df_tiktok_dataset = df_tiktok_dataset.apply(object_to_columns, 
                            authorMeta='authorMeta',  
                            musicMeta='musicMeta',
                            covers='cover',
                            videoMeta='videoMeta',
                            hashtags='hashtag', axis = 1)

# Remove the original columns containing the dictionaries
df_tiktok_dataset = df_tiktok_dataset.drop(['authorMeta','musicMeta','covers','videoMeta','hashtags'], axis = 1)
df_tiktok_dataset
# Out:
#                                      authorMeta.avatar        authorMeta.id  \
# 0    https://p16-sign-sg.tiktokcdn.com/aweme/1080x1...  6825540583826768902
# 1    https://p16-sign-va.tiktokcdn.com/musically-ma...  6729292817489986566
# 2    https://p16-sign-sg.tiktokcdn.com/aweme/1080x1...  6791901371429913601
# 2    https://p16-sign-sg.tiktokcdn.com/aweme/1080x1...  6791901371429913601
# 2    https://p16-sign-sg.tiktokcdn.com/aweme/1080x1...  6791901371429913601
# ..                                                 ...                  ...
# 999  https://p77-sign-sg.tiktokcdn.com/musically-ma...  6798143079889470469
# 999  https://p77-sign-sg.tiktokcdn.com/musically-ma...  6798143079889470469
# 999  https://p77-sign-sg.tiktokcdn.com/musically-ma...  6798143079889470469
# 999  https://p77-sign-sg.tiktokcdn.com/musically-ma...  6798143079889470469
# 999  https://p77-sign-sg.tiktokcdn.com/musically-ma...  6798143079889470469
#
#     authorMeta.name authorMeta.nickName  \
# 0         ninakleij                Nina
# 1          joeysofo           JoeySofo
# 2      jackeyephone           JackJacko
# 2      jackeyephone           JackJacko
# 2      jackeyephone           JackJacko
# ..              ...                 ...
# 999  erinwilliams_1       Erin Williams
# 999  erinwilliams_1       Erin Williams
# 999  erinwilliams_1       Erin Williams
# 999  erinwilliams_1       Erin Williams
# 999  erinwilliams_1       Erin Williams
#
#                                      authorMeta.secUid  \
# 0    MS4wLjABAAAA1FfFjRMUzr0hX2YPT7pRr7bCPQWa-kU_kV...
# 1    MS4wLjABAAAAvkCSTiPWJm7Ctqp7AN3mauS_Bi8tVrbtBg...
# 2    MS4wLjABAAAAsI8XQOceYtnIhIbLZLhvz24tOWdWYavlPe...
# 2    MS4wLjABAAAAsI8XQOceYtnIhIbLZLhvz24tOWdWYavlPe...
# 2    MS4wLjABAAAAsI8XQOceYtnIhIbLZLhvz24tOWdWYavlPe...
# ..                                                 ...
# 999  MS4wLjABAAAAdEeo7qMCWpjEHQIY8SBaOT4g79XSLKQz0l...
# 999  MS4wLjABAAAAdEeo7qMCWpjEHQIY8SBaOT4g79XSLKQz0l...
# 999  MS4wLjABAAAAdEeo7qMCWpjEHQIY8SBaOT4g79XSLKQz0l...
# 999  MS4wLjABAAAAdEeo7qMCWpjEHQIY8SBaOT4g79XSLKQz0l...
# 999  MS4wLjABAAAAdEeo7qMCWpjEHQIY8SBaOT4g79XSLKQz0l...
#
#                                   authorMeta.signature  authorMeta.verified  \
# 0              don’t tell my instagram I’m here\n19 👸🏼                False
# 1    Tinder couldn’t help me lose my virginity so I...                False
# 2    Zakelijk 📩 jackeyephone@gmail.com\nInstagram: ...                False
# 2    Zakelijk 📩 jackeyephone@gmail.com\nInstagram: ...                False
# 2    Zakelijk 📩 jackeyephone@gmail.com\nInstagram: ...                False
# ..                                                 ...                  ...
# 999  International Dressage Rider for GB 🇬🇧 \nIG: @...                False
# 999  International Dressage Rider for GB 🇬🇧 \nIG: @...                False
# 999  International Dressage Rider for GB 🇬🇧 \nIG: @...                False
# 999  International Dressage Rider for GB 🇬🇧 \nIG: @...                False
# 999  International Dressage Rider for GB 🇬🇧 \nIG: @...                False
#
#      commentCount                                      cover.default  \
# 0              68  https://p16-sign-sg.tiktokcdn.com/obj/tos-alis...
# 1             936  https://p16-sign-sg.tiktokcdn.com/obj/tos-mali...
# 2           27100  https://p16-sign-sg.tiktokcdn.com/obj/tos-alis...
# 2           27100  https://p16-sign-sg.tiktokcdn.com/obj/tos-alis...
# 2           27100  https://p16-sign-sg.tiktokcdn.com/obj/tos-alis...
# ..            ...                                                ...
# 999           874  https://p16-sign-sg.tiktokcdn.com/tos-alisg-p-...
# 999           874  https://p16-sign-sg.tiktokcdn.com/tos-alisg-p-...
# 999           874  https://p16-sign-sg.tiktokcdn.com/tos-alisg-p-...
# 999           874  https://p16-sign-sg.tiktokcdn.com/tos-alisg-p-...
# 999           874  https://p16-sign-sg.tiktokcdn.com/tos-alisg-p-...
#
#                                          cover.dynamic  ...  \
# 0    https://p16-sign-sg.tiktokcdn.com/obj/tos-alis...  ...
# 1    https://p16-sign-sg.tiktokcdn.com/obj/tos-mali...  ...
# 2    https://p16-sign-sg.tiktokcdn.com/obj/tos-alis...  ...
# 2    https://p16-sign-sg.tiktokcdn.com/obj/tos-alis...  ...
# 2    https://p16-sign-sg.tiktokcdn.com/obj/tos-alis...  ...
# ..                                                 ...  ...
# 999  https://p16-sign-sg.tiktokcdn.com/obj/tos-alis...  ...
# 999  https://p16-sign-sg.tiktokcdn.com/obj/tos-alis...  ...
# 999  https://p16-sign-sg.tiktokcdn.com/obj/tos-alis...  ...
# 999  https://p16-sign-sg.tiktokcdn.com/obj/tos-alis...  ...
# 999  https://p16-sign-sg.tiktokcdn.com/obj/tos-alis...  ...
#
#                                      musicMeta.playUrl  playCount  shareCount  \
# 0    https://sf16-sg.tiktokcdn.com/obj/tos-alisg-v-...      44800          50
# 1    https://sf77-sg.tiktokcdn.com/obj/musically-ma...     838100        1817
# 2    https://sf16-sg.tiktokcdn.com/obj/tos-alisg-v-...   15300000       21100
# 2    https://sf16-sg.tiktokcdn.com/obj/tos-alisg-v-...   15300000       21100
# 2    https://sf16-sg.tiktokcdn.com/obj/tos-alisg-v-...   15300000       21100
# ..                                                 ...        ...         ...
# 999  https://sf77-sg.tiktokcdn.com/obj/tiktok-obj/7...     309000         235
# 999  https://sf77-sg.tiktokcdn.com/obj/tiktok-obj/7...     309000         235
# 999  https://sf77-sg.tiktokcdn.com/obj/tiktok-obj/7...     309000         235
# 999  https://sf77-sg.tiktokcdn.com/obj/tiktok-obj/7...     309000         235
# 999  https://sf77-sg.tiktokcdn.com/obj/tiktok-obj/7...     309000         235
#
#                                                   text videoMeta.duration  \
# 0                                    Confidence went 📈                 15
# 1    Quiet Zone... follow me on insta: joeysofo. Co...                 11
# 2    Iphone bend test🤗 #tiktok #viral #fyp #iphone ...                 19
# 2    Iphone bend test🤗 #tiktok #viral #fyp #iphone ...                 19
# 2    Iphone bend test🤗 #tiktok #viral #fyp #iphone ...                 19
# ..                                                 ...                ...
# 999  The collab you didn’t know you needed, myself ...                 14
# 999  The collab you didn’t know you needed, myself ...                 14
# 999  The collab you didn’t know you needed, myself ...                 14
# 999  The collab you didn’t know you needed, myself ...                 14
# 999  The collab you didn’t know you needed, myself ...                 14
#
#     videoMeta.height videoMeta.width  \
# 0               1024             576
# 1               1024             576
# 2                960             540
# 2                960             540
# 2                960             540
# ..               ...             ...
# 999             1022             576
# 999             1022             576
# 999             1022             576
# 999             1022             576
# 999             1022             576
#
#                                               videoUrl videoUrlNoWaterMark  \
# 0    https://v77.tiktokcdn.com/ed1f811617d7b5e18b8d...
# 1    https://v77.tiktokcdn.com/ab935f1975cb8b69aebf...
# 2    https://v21.tiktokcdn.com/video/tos/alisg/tos-...
# 2    https://v21.tiktokcdn.com/video/tos/alisg/tos-...
# 2    https://v21.tiktokcdn.com/video/tos/alisg/tos-...
# ..                                                 ...                 ...
# 999  https://v77.tiktokcdn.com/a6a5e4b4310213520be7...
# 999  https://v77.tiktokcdn.com/a6a5e4b4310213520be7...
# 999  https://v77.tiktokcdn.com/a6a5e4b4310213520be7...
# 999  https://v77.tiktokcdn.com/a6a5e4b4310213520be7...
# 999  https://v77.tiktokcdn.com/a6a5e4b4310213520be7...
#
#                                            webVideoUrl
# 0    https://www.tiktok.com/@ninakleij/video/690722...
# 1    https://www.tiktok.com/@joeysofo/video/6875468...
# 2    https://www.tiktok.com/@jackeyephone/video/689...
# 2    https://www.tiktok.com/@jackeyephone/video/689...
# 2    https://www.tiktok.com/@jackeyephone/video/689...
# ..                                                 ...
# 999  https://www.tiktok.com/@erinwilliams_1/video/6...
# 999  https://www.tiktok.com/@erinwilliams_1/video/6...
# 999  https://www.tiktok.com/@erinwilliams_1/video/6...
# 999  https://www.tiktok.com/@erinwilliams_1/video/6...
# 999  https://www.tiktok.com/@erinwilliams_1/video/6...
#
# [5693 rows x 37 columns]
